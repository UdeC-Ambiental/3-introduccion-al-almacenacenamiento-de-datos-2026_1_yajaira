# %% [markdown]
# # 🧩 Ejemplo de clase – Introducción a Pandas
#
# Aprenderás los conceptos básicos de `pandas`, la creación de DataFrames y su exploración inicial.

# %%
import pandas as pd

# Crea un DataFrame base
datos = pd.DataFrame({
    'punto': [' A', ' B', 'C','D','E'], 
    'Temp':[22.25,24.3,19.8,23.65,25.15],
    'pH': [7.15,7.199999999999999, 6.85,7.05,7.25],
    'OD_promedio':[6.2,5.8,4.9,6.5,5.0]
})


datos.head()
# Out:
#   punto   Temp    pH  OD_promedio
# 0     A  22.25  7.15          6.2
# 1     B  24.30  7.20          5.8
# 2     C  19.80  6.85          4.9
# 3     D  23.65  7.05          6.5
# 4     E  25.15  7.25          5.0

# %% [markdown]
# ## 🧠 Reflexión
#
# Las ventajas que tiene usar 'pandas' es organizar los datos de una manera mas organizada visiblemente es decir en tablas a diferencia de listas o diccionarios ademas este cuneta con funciones para filtrar los datos
